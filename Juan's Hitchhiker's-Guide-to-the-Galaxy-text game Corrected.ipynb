# %%
#import functions to exit the code
from sys import exit
#import random functions to the game
import random
# Definition of tea and beer variables
#we have 6 variables for drinks black_tea, green_tea, 
#jazmine tea, white mango tea and whiskey
black_tea = 2
green_tea =2
beer = 2
jazmine_tea=2
white_mango_tea=2
whiskey= 2

#define the start of the scenes. 
#this is a small introduction to our galactic journey
def start():
    print(f"""This journey starts in a spaceship in the middle of the galaxy\n
    You {user_name} are seated in the living room with Trillian,""")
    print("""and Zaphod walk to the same place with a surprise face.""")
    print(" ")
    starting_path()

#This function show the different flavors of tea
def choice_tea1():
    #convert variables in int type
    int_black_tea = int(black_tea)
    int_green_tea = int(green_tea)
    int_beer = int(beer)
    
    print(f"""\n What flavors of tea do you have""")
    print("")
    #list of tea choices
    flavor_tea=["1. black", "2. green","3. we do have beer as well" ]
    #loop for flavor choices
    for flavor in flavor_tea:
        print(flavor, '\n')
    choice_flavor =input (prompt= "> \n").lower()
    if "1" in choice_flavor or "black" in choice_flavor:
        #count of black teas in the space ships
        if int_black_tea > 0:
            print("here is your black tea")
            int_black_tea -=1
            watch_video()
            return int_black_tea
        else:
            print("sorry we are out of black tea")
            
    
    elif "2" in choice_flavor or "green" in choice_flavor:
        #count of green teas in the space ships
        if int_green_tea > 0:
            print("here is your green tea")
            int_green_tea -=1
            watch_video()
            return int_green_tea
        else:
            print("sorry we are out of green tea")
            
    elif "3" in choice_flavor or "beer" in choice_flavor:
        #count of beer in the space ships
        if int_beer > 0:
            print("here is your beer")
            int_beer -=1
            watch_video()
            return int_beer
        else:
            print("sorry we are out of beer")
            
    else:
        print("sorry we dont have that onboard")
    watch_video()

#This function will take you immediately back to the start of your journey.    
def choice_tea2():
    
    #convert variables in int type
    int_jazmine_tea = int(jazmine_tea)
    int_white_mango_tea = int(white_mango_tea)
    int_whiskey = int(whiskey)
    
    print(f"""\n What flavors of tea do you have""")
    print("")
    #list of tea choices
    flavor_tea=["1. jazmine", "2. White mango","3. we do have Whiskey as well" ]
    #loop for flavor choices
    for flavor in flavor_tea:
        print(flavor, '\n')
    choice_flavor =input (prompt="> \n").lower()
    if "1" in choice_flavor or "Jazmine" in choice_flavor:
        #count of black teas in the space ships
        if int_jazmine_tea > 0:
            print("here is your Jazmine tea")
            int_jazmine_tea -=1

        else:
            print("sorry we are out of Jazmine tea")
    
    elif "2" in choice_flavor or "White" in choice_flavor or "Mango" in choice_flavor:
        #count of green teas in the space ships
        if int_white_mango_tea > 0:
            print("here is your White mango tea")
            int_white_mango_tea -=1

        else:
            print("sorry we are out of white mango tea")
            
    elif "3" in choice_flavor or "Whiskey" in choice_flavor:
        #count of beer in the space ships
        if int_whiskey > 0:
            print("here is your beer")
            int_whiskey -=1
            
        else:
            print("sorry we are out of whiskey")
            
    else:
        print("sorry we dont have that onboard")
    starting_path()

#This function will ask randomly the tea question    
def random_tea():
    guess_number= random.randint(a = 1,  # this is for tea option 1
               b = 2) # this for tea option 2
    if guess_number==1:
        choice_tea1()
    elif guess_number!=1:
        choice_tea2()
    else:
        #If you get this, is a bug!!!! 
        print("Something is wrong this is a bug")
    
    

#This is the function to start our choices. 
#In other words this is the first 
#scene of our path
def starting_path():   
    print(f"""\n As the leader of this journey you have to make a choice:\n
    1. Ask Zaphod what happened?
    2. Ignore Zaphod and keep seat looking the amazing galaxy throught the window
    3. Ask for a tea to Marvin
    """)
    #need to introduce a nested condition here for which tea do you want! 
    #1. for black tea, 2. for green tea 3.  I need booz
    
    choice = input(prompt=">  \n").lower()
    
    if "1" in choice or "Ask Zaphod" in choice or "What happened" in choice:
        #this option will contonue with the current story
        print("""\n I had to divide my head in two """)
        print(f""" {user_name} scream: you did what? why? """)
        print("""Zaphod answers: yes apparently you can't be the galaxy president with a whole brain""")
        print("So I divide in two, but... I'm holding this and I don't remember why")
        watch_video()
    elif "2" in choice or "look at the window" in choice or "Ignore" in choice:
        #this option will finalize the game
        print("\nWell I guess the journey is over. Good-bye!")
        end_game_q()
    elif "3"in choice or "tea" in choice or "ask for tea" in choice:
        #This option will start the tea options 
        #and then will restart the previous question
        print("Marvin says ironically: well this is the most important life cycle")
        print("of an intergalactic robot, bring tea to a guest")
        print("Marvin says ironically: yei!")
        print("")
        print(f""" now what? {user_name}, what would we do now?""")
        random_tea()
    else:
        print("Invalid command. Please try again.")
        starting_path()

#this function is the second stage of our journey. 
def watch_video():
    print(f"""\n Zaphod has a digital video record in his hands with absolutely important information
    """)
    print(f""" {user_name} What will you do now?""")
    
    print(f"""
    1. Play the video?
    2. Ignore Zaphod and the video?
    3. Ask for another tea to Marvin
    """)
    choice=input(prompt=">   \n").lower()
    if "1" in choice or "play video" in choice or "video" in choice:
        #This option will continue the current game
        print("""\n   """)
        print("marvin says: I've seen it before, is rubish")
        print(" ")
        print("Zaphod: when I saw what I'm about to show you")
        print("that's when I realized why I did what I did to my brain") 
        print("or it least, I think that's why.")
        print(" ")
        print("The record star playing ")
        
        print("The screen brightens. A BRAND LOGO appears\n (a circle made\
        of a dotted line with an M in the middle)\n  \
        then a sub-title: MAGRATHEAN PUBLIC ARCHIVE. \n \
        Zaphod fast forwards until a noisy picture DISSOLVES TO...")
        
        print("")
        print("A procession surrounds a CHARIOT. Two young philosophers,\n \
        LUNKWILL and FOOK (20'S) ride it into a grand TEMPLE.")
        
        print("The aisles are lined with Priest-Technicians. Ahead is \n \
        DEEP THOUGHT - a huge Buddha-esque computer. \n \
        The procession peels away to both sides. \n  \
        Lunkwill and Fook dismount and approach.")
        
        print("Deep thought (Yes this is the name of the super computer): What is this great task for which I,\n \
        Deep Thought, the second greatest computer of all time have been called into existence?")
        
        print("")
        
        print("""The philosophers: Oh Deep Thought, your task is this. \n \ 
              We want you to tell us -- the Answer.""")
        
        print("Deep thought: The Answer...to what?")
        
        print("")
        
        print("""The philosophers: You know. The answer. \n \      
        To Life...the Universe...Everything.""")
        
        print("""Deep Thought: The Ultimate Question of Life, the Universe and Everything.\n \
        Yes. There is an answer. But I'll have to think about it. \n \
        Return to this place in exactly... seven and a half million years.""")
        
        print (""" ___________                                                   
|___  /  ___|                                                  
   / /|___ \   _ __ ___  _ __ ___    _   _  ___  __ _ _ __ ___ 
  / /     \ \ | '_ ` _ \| '_ ` _ \  | | | |/ _ \/ _` | '__/ __|
./ /  /\__/ / | | | | | | | | | | | | |_| |  __/ (_| | |  \__ \
\_(_) \____/  |_| |_| |_|_| |_| |_|  \__, |\___|\__,_|_|  |___/
                                      __/ |                    
                                     |___/                     """)
        wait_million_years()
           
    elif "2" in choice or "Ignore Zaphod" in choice or "Ignore" in choice:
        #This will finalize the current game, 
        #but you will have a start over question
        print("\nWell I guess the journey is over. Good-bye!")
        end_game_q()
    elif "3" in choice or "tea" in choice or "ask for tea" in choice:
        #This option will send you again to the teas stages 
        #and then will re connect the game with the previous question
        print("Marvin says ironically: well this is the second most important life cycle") 
        print("of an intergalactic robot")
        print("bring tea to a guest""")
        print("Marvin says ironically: yei! another tea")
        print("")
        #place a random function to choose between tea 1 or tea 2
        
        random_tea()
        
        print(f"""{user_name}, now that you have your tea in your hands. What now? """)
        watch_video()
    else:
        #This would never happen, if it happens is a bug
        print("Invalid command. Please try again.")
        input(prompt="<Press enter to continue>\n").lower()
        watch_video()
    
#this is the third stage of our journey. 7.5 million years later
def wait_million_years():
    print("After 7.5 million year of waiting, you must be tired at the end")
    print (" ")
    print("why dont you ask Marvin for another tea")
    
    print("""  .----------------.  .----------------.  .----------------.   .----------------.  .----------------.  .----------------. 
| .--------------. || .--------------. || .--------------. | | .--------------. || .--------------. || .--------------. |
| |     _____    | || |     ______   | || |  _________   | | | |  _________   | || |  _________   | || |      __      | |
| |    |_   _|   | || |   .' ___  |  | || | |_   ___  |  | | | | |  _   _  |  | || | |_   ___  |  | || |     /  \     | |
| |      | |     | || |  / .'   \_|  | || |   | |_  \_|  | | | | |_/ | | \_|  | || |   | |_  \_|  | || |    / /\ \    | |
| |      | |     | || |  | |         | || |   |  _|  _   | | | |     | |      | || |   |  _|  _   | || |   / ____ \   | |
| |     _| |_    | || |  \ `.___.'\  | || |  _| |___/ |  | | | |    _| |_     | || |  _| |___/ |  | || | _/ /    \ \_ | |
| |    |_____|   | || |   `._____.'  | || | |_________|  | | | |   |_____|    | || | |_________|  | || ||____|  |____|| |
| |              | || |              | || |              | | | |              | || |              | || |              | |
| '--------------' || '--------------' || '--------------' | | '--------------' || '--------------' || '--------------' |
 '----------------'  '----------------'  '----------------'   '----------------'  '----------------'  '----------------'  """)
    print("")
    random_tea()

#this is the final stage of our journey, 
#where our heroes will get the great answer to everythin
def answer_deep_tought():
    print("""\n After 7.5 million years, the philosophers enter the now modern temple, \n \
    flanked by a crowd. They have beards and look like they're in their 40's.\n
    Deep Thought rises, looks lifeless. \n
    WORRIED MUTTERS FROM THE CROWD. Slowly, Deep Thought groans to life.""")
    print("")
    print("The philosophers: Do you have the answer? ")
    print("""Deep tought:yes, and You will not like the answer, \n \
    I hope you had enjoyed your tea""")
    print("The philosophers:  Doesn't matter! We must know it!")
    print("")
    print("You're really not going to like it.")
    print("The philosophers:  Tell us!")
    
    print("")
    
    print("""Deep Thought: Alright. The answer to the ultimate question \n
    of Life, the Universe, and Everything \n
    is...\n
    Forty two""")
    
    print("""  _   ___  _______ 
| | |   ||       |
| |_|   ||____   |
|       | ____|  |
|___    || ______|
    |   || |_____ 
    |___||_______|""")
    
    end_game_q()
    
def end_game_q():    
    #This function will ask you if you want to start over the game
    choice =input(prompt="""Do you want to play again? 
    Yes
    No\n
    """).lower()
    if "yes" in choice :
        start()
    elif "no" in choice:
        fail()
    else:
    #If this option happens means that you found an actual bug
        print("wrong option ")
        start()

def fail():
    print("Thanks so much for playing. This is the end of your game")
        
#you will be part of this journey please introduce your name
user_name= input(prompt= "Please introduce your name: ").capitalize()

#This is a small introduction of what is going to happen
def initial_stage():
    print (f""" 
    Oh my dear {user_name}, the following adventure its based in the \n
    Hitchhiker's-Guide-to-the-Galaxy from 2005. """)
    print("""I know is not the original one,\n
    but I really enjoyed this version, lol.""")

    print(f"""The whole story starts when {user_name}, is joining our story heroes 
    Trillian, Arthur, Ford, Zaphod and Marvin""") 
    print("---" *30)

initial_stage()    
start()
# Out:
# Please introduce your name: juab
#
#     Oh my dear Juab, the following adventure its based in the
#
#     Hitchhiker's-Guide-to-the-Galaxy from 2005.
# I know is not the original one,
#
#     but I really enjoyed this version, lol.
# The whole story starts when Juab, is joining our story heroes
#     Trillian, Arthur, Ford, Zaphod and Marvin
# ------------------------------------------------------------------------------------------
# This journey starts in a spaceship in the middle of the galaxy
#
#     You Juab are seated in the living room with Trillian,
# and Zaphod walk to the same place with a surprise face.
#
#
#  As the leader of this journey you have to make a choice:
#
#     1. Ask Zaphod what happened?
#     2. Ignore Zaphod and keep seat looking the amazing galaxy throught the window
#     3. Ask for a tea to Marvin
#
# >
# 3
# Marvin says ironically: well this is the most important life cycle
# of an intergalactic robot, bring tea to a guest
# ...
